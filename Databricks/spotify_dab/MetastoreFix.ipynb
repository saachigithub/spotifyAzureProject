# %%
import requests
import json

host = " "
token = " "

payload = {
    "storage_root_credential_id": "  "
}

response = requests.patch(
    f"{host}/api/2.1/unity-catalog/metastores/1e8a386a-b82f-4108-9647-83cc31a01cf7",
    headers={
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json"
    },
    json=payload
)

print("Status:", response.status_code)
print(response.text)

# %%
import requests
import json

host = " "
token = " "

payload = {
    "storage_root": " ",
    "storage_root_credential_id": " "
}

r = requests.patch(
    f"{host}/api/2.1/unity-catalog/metastores/1e8a386a-b82f-4108-9647-83cc31a01cf7",
    headers={
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json"
    },
    json=payload
)

print(r.status_code)
print(r.text)

# %%
import requests, json

host = " "
token = " "

r = requests.get(
    f"{host}/api/2.1/unity-catalog/metastores/1e8a386a-b82f-4108-9647-83cc31a01cf7",
    headers={"Authorization": f"Bearer {token}"}
)

print(json.dumps(r.json(), indent=2))
