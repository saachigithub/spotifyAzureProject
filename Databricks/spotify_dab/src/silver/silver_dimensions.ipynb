# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### **DimUser**

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os
import sys

project_pth= os.path.join(os.getcwd(),"..","..")
sys.path.append(project_pth)

from utils.transformations import reusable

# %%
df = spark.read.format("parquet")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/DimUser")

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ### **Autoloader**

# %%
df_user = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "parquet")\
    .option("cloudFiles.schemaLocation", "abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/checkpoint")\
    .option("schemaEvolutionMode", "addNewColumns")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/DimUser")

# %% [markdown]
# wrote 2 cmd same display wali error de rahi thi and imported library and worked

# %%
display(
    df_user,
    checkpointLocation="abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/checkpoint"
)
# Out:
# Checkpointing to abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/checkpoint
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6144125844261874>, line 1
# ----> 1 display(
#       2     df_user,
#       3     checkpointLocation="abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/checkpoint"
#       4 )
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:97, in Display.display_connect_table(self, df, **kwargs)
#      92     raise type(
#      93         e
# ...

# %%
df_user.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6144125844261880>, line 1
# ----> 1 df_user.show()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1156, in DataFrame.show(self, n, truncate, vertical)
#    1155 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1156     print(self._show_string(n, truncate, vertical))
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:909, in DataFrame._show_string(self, n, truncate, vertical)
#     892     except ValueError:
#     893         raise PySparkTypeError(
#     894             errorClass="NOT_BOOL",
#     895             messageParameters={
#    (...)
#     898             },
#     899         )
#     901 table, _ = DataFrame(
#     902     plan.ShowString(
# ...

# %%
df_user.isStreaming
# Out:
# True

# %%
df_user = df_user.withColumn("user_name",upper(col("user_name")))

# %%
display(df_user)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6144125844261882>, line 1
# ----> 1 display(df_user)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:97, in Display.display_connect_table(self, df, **kwargs)
#      92     raise type(
#      93         e
#      94     )("IPython shell encountered an error or was missing data, please restart the notebook or contact Databricks support"
#      95       ) from e
#      96 if df.isStreaming:
# ...

# %%
df_user_obj = reusable()
df_user = df_user_obj.dropColumns(df_user,['_rescued_data'])
df_user = df_user.dropDuplicates(['user_id'])

# %%
display(df_user)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4966744600588498>, line 1
# ----> 1 display(df_user)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:97, in Display.display_connect_table(self, df, **kwargs)
#      92     raise type(
#      93         e
#      94     )("IPython shell encountered an error or was missing data, please restart the notebook or contact Databricks support"
#      95       ) from e
#      96 if df.isStreaming:
# ...

# %%
print(df_user.isStreaming)
# Out:
# True

# %%
df_user.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/checkpoint")\
    .trigger(once=True)\
    .option("path","abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/data")\
    .toTable("spotify_cata.silver.DimUser")

# %%
display(
    spark.read.format("delta")
    .load("abfss://silver@storagespotify189.dfs.core.windows.net/DimUser/data")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## **DimArtist**

# %%
df_art = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "parquet")\
    .option("cloudFiles.schemaLocation", "abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/checkpoint")\
    .option("schemaEvolutionMode", "addNewColumns")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/DimArtist")

# %%
display(df_art, checkpointLocation ="abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/checkpoint")
# Out:
# Checkpointing to abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/checkpoint

# %%
display(df_art)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-9001483499399254>, line 1
# ----> 1 display(df_art)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:97, in Display.display_connect_table(self, df, **kwargs)
#      92     raise type(
#      93         e
#      94     )("IPython shell encountered an error or was missing data, please restart the notebook or contact Databricks support"
#      95       ) from e
#      96 if df.isStreaming:
# ...

# %%
df_art = df_art.withColumn("artist_name",upper(col("artist_name")))

# %%
df_art_obj = reusable()
df_art = df_art_obj.dropColumns(df_art,['_rescued_data'])

# %%
df_art = df_art.dropDuplicates(['artist_id'])

# %%
df_art.isStreaming
# Out:
# True

# %%
df_art.printSchema()
# Out:
# root
#  |-- artist_id: integer (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
df_art.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/checkpoint")\
    .trigger(once=True)\
    .option("path","abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/data")\
    .toTable("spotify_cata.silver.DimArtist")

# %%
display(
    spark.read.format("delta")
    .load("abfss://silver@storagespotify189.dfs.core.windows.net/DimArt/data")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## **DimTrack**

# %%
df_track = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "parquet")\
    .option("cloudFiles.schemaLocation", "abfss://silver@storagespotify189.dfs.core.windows.net/DimTrack/checkpoint")\
    .option("schemaEvolutionMode", "addNewColumns")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/DimTrack")

# %%
df_track= df_track.withColumn("durationFlag", when(col('duration_sec')<150, "low")\
    .when(col('duration_sec')<300, "medium")\
    .otherwise("high"))
df_track = df_track.withColumn("track_name", regexp_replace(col("track_name"),'-',' '))
df_track = reusable().dropColumns(df_track,['_rescued_data'])

# %%
df_track.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","abfss://silver@storagespotify189.dfs.core.windows.net/DimTrack/checkpoint")\
    .trigger(once=True)\
    .option("path","abfss://silver@storagespotify189.dfs.core.windows.net/DimTrack/data")\
    .toTable("spotify_cata.silver.DimTrack")

# %%
display(
    spark.read.format("delta")
    .load("abfss://silver@storagespotify189.dfs.core.windows.net/DimTrack/data")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## **DimDate**

# %%
df_date = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "parquet")\
    .option("cloudFiles.schemaLocation", "abfss://silver@storagespotify189.dfs.core.windows.net/DimDate/checkpoint")\
    .option("schemaEvolutionMode", "addNewColumns")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/DimDate")

# %%
df_date = reusable().dropColumns(df_date,['_rescued_data'])

# %%
df_date.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","abfss://silver@storagespotify189.dfs.core.windows.net/DimDate/checkpoint")\
    .trigger(once=True)\
    .option("path","abfss://silver@storagespotify189.dfs.core.windows.net/DimDate/data")\
    .toTable("spotify_cata.silver.DimDate")

# %%
display(
    spark.read.format("delta")
    .load("abfss://silver@storagespotify189.dfs.core.windows.net/DimDate/data")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## **FactStream**

# %%
df_fact = spark.readStream.format("cloudFiles")\
    .option("cloudFiles.format", "parquet")\
    .option("cloudFiles.schemaLocation", "abfss://silver@storagespotify189.dfs.core.windows.net/FactStream/checkpoint")\
    .option("schemaEvolutionMode", "addNewColumns")\
    .load("abfss://bronze@storagespotify189.dfs.core.windows.net/FactStream")

# %%
df_batch = spark.read.format("parquet").load(
    "abfss://bronze@storagespotify189.dfs.core.windows.net/FactStream"
)

df_batch.show(20, truncate=False)
# Out:
# +---------+-------+--------+--------+---------------+-------------+-------------------+
# |stream_id|user_id|track_id|date_key|listen_duration|device_type  |stream_timestamp   |
# +---------+-------+--------+--------+---------------+-------------+-------------------+
# |1        |361    |74      |20250518|156            |Smart Speaker|2025-09-30 19:49:55|
# |2        |321    |288     |20250519|47             |Mobile       |2025-09-27 19:49:55|
# |3        |275    |340     |20250307|214            |Mobile       |2025-10-03 19:49:55|
# |4        |43     |373     |20250216|14             |Desktop      |2025-10-04 19:49:55|
# |5        |319    |95      |20250421|266            |Desktop      |2025-09-27 19:49:55|
# |6        |52     |31      |20250130|317            |Desktop      |2025-10-02 19:49:55|
# |7        |5      |354     |20250824|90             |Mobile       |2025-10-01 19:49:55|
# |8        |115    |386     |20250413|159            |Smart Speaker|2025-09-29 19:49:55|
# ...

# %%
df_fact = reusable().dropColumns(df_fact,['_rescued_data'])

# %%
df_fact.writeStream.format("delta")\
    .outputMode("append")\
    .option("checkpointLocation","abfss://silver@storagespotify189.dfs.core.windows.net/FactStream/checkpoint")\
    .trigger(once=True)\
    .option("path","abfss://silver@storagespotify189.dfs.core.windows.net/FactStream/data")\
    .toTable("spotify_cata.silver.FactStream")

# %%
display(
    spark.read.format("delta")
    .load("abfss://silver@storagespotify189.dfs.core.windows.net/FactStream/data")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from spotify_cata.gold.dimtrack where `__END_AT` is not null;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from spotify_cata.gold.dimtrack 
where track_id in (46,5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
